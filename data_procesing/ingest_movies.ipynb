# %% [markdown]
# ### Install dependencies

# %%
import requests
import os 
from dotenv import load_dotenv
import time
import pandas as pd
from sqlalchemy import create_engine, text
from sklearn.preprocessing import MinMaxScaler
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 7
#       5 import pandas as pd
#       6 from sqlalchemy import create_engine, text
# ----> 7 from sklearn.preprocessing import MinMaxScaler
#
# File c:\Users\34651\Desktop\python_projects\movie-recomendation-system\.venv\lib\site-packages\sklearn\__init__.py:73
#      62 # `_distributor_init` allows distributors to run custom init code.
#      63 # For instance, for the Windows wheel, this is used to pre-load the
#      64 # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)
#      67 # later is linked to the OpenMP runtime to make it possible to introspect
#      68 # it and importing it first would fail if the OpenMP dll cannot be found.
#      69 from . import (  # noqa: F401 E402
#      70     __check_build,
#      71     _distributor_init,
#      72 )
# ...

# %%
load_dotenv()

# API key for TMDB API
API_KEY = os.getenv("TMDB_API_KEY")


# Function to get popular movies information
def get_movies_information(oage):

    # Endpoint for popular movies
    url = "https://api.themoviedb.org/3/movie/popular"

    params = {
        "api_key": API_KEY,
        "language": "en-US",
        "page": page
    }

    response = requests.get(url, params=params)

    if response.status_code != 200:
        print(f"Error: {response.status_code}")
        return []

    return response.json()["results"]

all_movies = []

# We will fetch the first 100 pages of popular movies.
for page in range(1, 101):
    print(f"Dowloading page {page}...")
    movies = get_movies_information(page)
    all_movies.extend(movies)

    time.sleep(0.25) # Sleep for 250ms to avoid hitting the rate limit
          
print("Films information: ", len(all_movies))
# Out:
# Dowloading page 1...
# Dowloading page 2...
# Dowloading page 3...
# Dowloading page 4...
# Dowloading page 5...
# Dowloading page 6...
# Dowloading page 7...
# Dowloading page 8...
# Dowloading page 9...
# Dowloading page 10...
# Dowloading page 11...
# Dowloading page 12...
# Dowloading page 13...
# Dowloading page 14...
# Dowloading page 15...
# Dowloading page 16...
# Dowloading page 17...
# Dowloading page 18...
# Dowloading page 19...
# Dowloading page 20...
# Dowloading page 21...
# Dowloading page 22...
# Dowloading page 23...
# Dowloading page 24...
# Dowloading page 25...
# Dowloading page 26...
# Dowloading page 27...
# Dowloading page 28...
# Dowloading page 29...
# Dowloading page 30...
# Dowloading page 31...
# Dowloading page 32...
# Dowloading page 33...
# Dowloading page 34...
# Dowloading page 35...
# Dowloading page 36...
# Dowloading page 37...
# Dowloading page 38...
# Dowloading page 39...
# Dowloading page 40...
# Dowloading page 41...
# Dowloading page 42...
# ...

# %%
all_movies
# Out:
# [{'adult': False,
#   'backdrop_path': '/kxQiIJ4gVcD3K6o14MJ72p5yRcE.jpg',
#   'genre_ids': [10751, 35, 12, 14, 16],
#   'id': 1226863,
#   'original_language': 'en',
#   'original_title': 'The Super Mario Galaxy Movie',
#   'overview': "Having thwarted Bowser's previous plot to marry Princess Peach, Mario and Luigi now face a fresh threat in Bowser Jr., who is determined to liberate his father from captivity and restore the family legacy. Alongside companions new and old, the brothers travel across the stars to stop the young heir's crusade.",
#   'popularity': 828.4621,
#   'poster_path': '/eJGWx219ZcEMVQJhAgMiqo8tYY.jpg',
#   'release_date': '2026-04-01',
#   'title': 'The Super Mario Galaxy Movie',
#   'video': False,
#   'vote_average': 6.8,
#   'vote_count': 529},
#  {'adult': False,
#   'backdrop_path': '/1x9e0qWonw634NhIsRdvnneeqvN.jpg',
#   'genre_ids': [10749, 18],
#   'id': 1523145,
#   'original_language': 'ru',
#   'original_title': 'Твоё сердце будет разбито',
# ...

# %%
df = pd.DataFrame(all_movies)

# %%
df["word_count"] = df["overview"].apply(lambda x: len(str(x).split()))
df
# Out:
#       adult                     backdrop_path                genre_ids  \
# 0     False  /kxQiIJ4gVcD3K6o14MJ72p5yRcE.jpg  [10751, 35, 12, 14, 16]
# 1     False  /1x9e0qWonw634NhIsRdvnneeqvN.jpg              [10749, 18]
# 2     False  /u8DU5fkLoM5tTRukzPC31oGPxaQ.jpg            [878, 12, 14]
# 3     False  /sS3zGYFPcfM5pArVNWl6qLyaSmU.jpg         [16, 28, 12, 14]
# 4     False  /gM1kQRPwOVW1Eos5tVWqcYmHR5S.jpg               [27, 9648]
# ...     ...                               ...                      ...
# 1995  False  /zb7b40ieuRGiIc9ebIEapneaCsl.jpg                 [18, 28]
# 1996  False  /12RXkIWUXwOHXgAmlxJNIWRGrri.jpg             [37, 35, 18]
# 1997  False  /lyzI5uFJC2E7sIYCCdaU0oZkDw2.jpg          [16, 10751, 14]
# 1998  False  /vDFhaKEMKPIUePtQH2nOwSHfgPy.jpg             [35, 14, 27]
# 1999  False  /3TeGmKJfkik1D1rIoqGb1aR4k9c.jpg            [12, 28, 878]
#
#            id original_language                             original_title  \
# ...

# %%
# Remove movies with less than 20 words in the overview, as they may not provide enough information for recommendations.
df = df[df["word_count"] > 20]

# %%
len(df)
# Out:
# 1879

# %%
# To uncrypt the genre ids, we need to make another call to the API.

def get_genres():
    url = "https://api.themoviedb.org/3/genre/movie/list"

    params = {
        "api_key": API_KEY,
        "language": "en-US"
    }

    response = requests.get(url, params=params)

    return response.json()["genres"]

genres = get_genres()

genres
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 36, 'name': 'History'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 9648, 'name': 'Mystery'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 10770, 'name': 'TV Movie'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 10752, 'name': 'War'},
#  {'id': 37, 'name': 'Western'}]

# %%
# Change the structure of the genres list
new_genres_dict = {genre["id"]: genre["name"] for genre in genres} 
new_genres_dict
# Out:
# {28: 'Action',
#  12: 'Adventure',
#  16: 'Animation',
#  35: 'Comedy',
#  80: 'Crime',
#  99: 'Documentary',
#  18: 'Drama',
#  10751: 'Family',
#  14: 'Fantasy',
#  36: 'History',
#  27: 'Horror',
#  10402: 'Music',
#  9648: 'Mystery',
#  10749: 'Romance',
#  878: 'Science Fiction',
#  10770: 'TV Movie',
#  53: 'Thriller',
#  10752: 'War',
#  37: 'Western'}

# %%
# Create a new column with the genre names instead of the ids.
df["genres"] = df["genre_ids"].apply(lambda ids: [new_genres_dict.get(i) for i in ids] )
# Out:
# C:\Users\34651\AppData\Local\Temp\ipykernel_26264\440369914.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["genres"] = df["genre_ids"].apply(lambda ids: [new_genres_dict.get(i) for i in ids] )

# %%
df["genres"]
# Out:
# 0       [Family, Comedy, Adventure, Fantasy, Animation]
# 1                                      [Romance, Drama]
# 2                 [Science Fiction, Adventure, Fantasy]
# 3               [Animation, Action, Adventure, Fantasy]
# 4                                     [Horror, Mystery]
#                              ...
# 1995                                    [Drama, Action]
# 1996                           [Western, Comedy, Drama]
# 1997                       [Animation, Family, Fantasy]
# 1998                          [Comedy, Fantasy, Horror]
# 1999               [Adventure, Action, Science Fiction]
# Name: genres, Length: 1879, dtype: object

# %%
# Make sure that the genres columns has no errors
df["errors"] = df["genres"].apply(lambda ids: any(i not in new_genres_dict.values() for i in ids))

# If it is false, there is no erros, if it is true, there is an error.
df[df["errors"] == True]
# Out:
# C:\Users\34651\AppData\Local\Temp\ipykernel_26264\281246137.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["errors"] = df["genres"].apply(lambda ids: any(i not in new_genres_dict.values() for i in ids))
# Empty DataFrame
# Columns: [adult, backdrop_path, genre_ids, id, original_language, original_title, overview, popularity, poster_path, release_date, title, video, vote_average, vote_count, word_count, genres, errors]
# Index: []

# %%
# Check if the genres_columns has any null values or empty lists.
len(df[df["genres"].isnull() | (df["genres"].apply(lambda x: len(x) == 0))])
# Out:
# 4

# %%
# As there are few rows with empty genres, we can drop them.
df = df[~(df["genres"].isnull() | (df["genres"].apply(lambda x: len(x) == 0)))]

# %%
df.columns
# Out:
# Index(['adult', 'backdrop_path', 'genre_ids', 'id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'release_date', 'title', 'video', 'vote_average', 'vote_count',
#        'word_count', 'genres', 'errors'],
#       dtype='object')

# %%
df
# Out:
#       adult                     backdrop_path                genre_ids  \
# 0     False  /kxQiIJ4gVcD3K6o14MJ72p5yRcE.jpg  [10751, 35, 12, 14, 16]
# 1     False  /1x9e0qWonw634NhIsRdvnneeqvN.jpg              [10749, 18]
# 2     False  /u8DU5fkLoM5tTRukzPC31oGPxaQ.jpg            [878, 12, 14]
# 3     False  /sS3zGYFPcfM5pArVNWl6qLyaSmU.jpg         [16, 28, 12, 14]
# 4     False  /gM1kQRPwOVW1Eos5tVWqcYmHR5S.jpg               [27, 9648]
# ...     ...                               ...                      ...
# 1995  False  /zb7b40ieuRGiIc9ebIEapneaCsl.jpg                 [18, 28]
# 1996  False  /12RXkIWUXwOHXgAmlxJNIWRGrri.jpg             [37, 35, 18]
# 1997  False  /lyzI5uFJC2E7sIYCCdaU0oZkDw2.jpg          [16, 10751, 14]
# 1998  False  /vDFhaKEMKPIUePtQH2nOwSHfgPy.jpg             [35, 14, 27]
# 1999  False  /3TeGmKJfkik1D1rIoqGb1aR4k9c.jpg            [12, 28, 878]
#
#            id original_language                             original_title  \
# ...

# %%
df.columns
# Out:
# Index(['adult', 'backdrop_path', 'genre_ids', 'id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'release_date', 'title', 'video', 'vote_average', 'vote_count',
#        'word_count', 'genres', 'errors'],
#       dtype='object')

# %%
important_columns = ['adult', 'id', 'original_language',
       'original_title', 'overview', 'popularity',
       'release_date', 'title', 'vote_average', 'vote_count',
       'genres']

# %%
df_final = df[important_columns]
df_final
# Out:
#       adult       id original_language  \
# 0     False  1226863                en
# 1     False  1523145                ru
# 2     False    83533                en
# 3     False   980431                en
# 4     False  1470130                en
# ...     ...      ...               ...
# 1995  False    59440                en
# 1996  False   537996                en
# 1997  False      756                en
# 1998  False     9374                en
# 1999  False     1893                en
#
#                                  original_title  \
# 0                  The Super Mario Galaxy Movie
# 1                     Твоё сердце будет разбито
# 2                          Avatar: Fire and Ash
# 3              Avatar: Aang, The Last Airbender
# 4                        The Mortuary Assistant
# ...                                         ...
# 1995                                    Warrior
# 1996               The Ballad of Buster Scruggs
# 1997                                   Fantasia
# ...

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1875 entries, 0 to 1999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              1875 non-null   bool
#  1   id                 1875 non-null   int64
#  2   original_language  1875 non-null   object
#  3   original_title     1875 non-null   object
#  4   overview           1875 non-null   object
#  5   popularity         1875 non-null   float64
#  6   release_date       1875 non-null   object
#  7   title              1875 non-null   object
#  8   vote_average       1875 non-null   float64
#  9   vote_count         1875 non-null   int64
#  10  genres             1875 non-null   object
# dtypes: bool(1), float64(2), int64(2), object(6)
# memory usage: 163.0+ KB

# %%
# We are going to create a column called "weighted_rating" that will be a weighted average of the vote_average and the popularity of the movie. This will help us to have a better recommendation system.
# This formula computes a weighted rating that balances a movie’s own average rating with the global average rating, giving more influence to movies with a higher number of votes. It reduces the bias of movies with few votes by gradually trusting the global mean when the vote count is low and the movie’s own rating when the vote count is high.
df_final["weighted_rating"] = (
    df_final["vote_count"] / (df_final["vote_count"] + 1000) * df_final["vote_average"]
    + 1000 / (df_final["vote_count"] + 1000) * df_final["vote_average"].mean()
)
# Out:
# C:\Users\34651\AppData\Local\Temp\ipykernel_26264\1480674201.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["weighted_rating"] = (

# %%
df_final.columns
# Out:
# Index(['adult', 'id', 'original_language', 'original_title', 'overview',
#        'popularity', 'release_date', 'title', 'vote_average', 'vote_count',
#        'genres', 'weighted_rating'],
#       dtype='object')

# %%
# We are going to normalize the numeric columns.
# Normalize the numeric columns
# Delete the vote_count column as it is not useful for the recommendation system and it is highly correlated with the weighted_rating column.
df_final2 = df_final.copy()
scaler = MinMaxScaler()
df_final2[["popularity", "vote_average", "weighted_rating"]] = scaler.fit_transform(df_final2[["popularity", "vote_average", "weighted_rating"]])

# %%
df_final2 = df_final2.drop(columns=["vote_count"])

# %%
# We are going to create a new column called "content" with the information of the title, overview and genres of the movie.
# We have to apply a lambda function to the genres column to convert the list of genres into a string.
df_final2["genres_text"] = df_final2["genres"].apply(lambda x: " ".join(x))
df_final2["content"] = (
    "id: " + df_final2["id"].astype(str) + ". " +
    "title: " + df_final2["title"].fillna("") + ". " +
    "overview: " + df_final2["overview"].fillna("") + ". " +
    "genres: " + df_final2["genres_text"].fillna("")
)

df_final2
# Out:
#       adult       id original_language  \
# 0     False  1226863                en
# 1     False  1523145                ru
# 2     False    83533                en
# 3     False   980431                en
# 4     False  1470130                en
# ...     ...      ...               ...
# 1995  False    59440                en
# 1996  False   537996                en
# 1997  False      756                en
# 1998  False     9374                en
# 1999  False     1893                en
#
#                                  original_title  \
# 0                  The Super Mario Galaxy Movie
# 1                     Твоё сердце будет разбито
# 2                          Avatar: Fire and Ash
# 3              Avatar: Aang, The Last Airbender
# 4                        The Mortuary Assistant
# ...                                         ...
# 1995                                    Warrior
# 1996               The Ballad of Buster Scruggs
# 1997                                   Fantasia
# ...

# %%
# Drop duplicates grouping by id, as it is the primary key of the table.
df_final2 = df_final2.drop_duplicates(subset=["id"])

# Create a column with the year of the release date, as it can be useful for the recommendation system.
df_final2["release_year"] = pd.to_datetime(df_final2["release_date"], errors="coerce").dt.year

df_final2
# Out:
# C:\Users\34651\AppData\Local\Temp\ipykernel_26264\2722012765.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final2["release_year"] = pd.to_datetime(df_final2["release_date"], errors="coerce").dt.year
#       adult       id original_language  \
# 0     False  1226863                en
# 1     False  1523145                ru
# 2     False    83533                en
# 3     False   980431                en
# 4     False  1470130                en
# ...     ...      ...               ...
# 1995  False    59440                en
# 1996  False   537996                en
# 1997  False      756                en
# 1998  False     9374                en
# 1999  False     1893                en
#
# ...

# %%
# Cast the release_year to string
df_final2["release_year"] = df_final2["release_year"].astype("Int64")
df_final2
# Out:
# C:\Users\34651\AppData\Local\Temp\ipykernel_26264\3167087810.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final2["release_year"] = df_final2["release_year"].astype("Int64")
#       adult       id original_language  \
# 0     False  1226863                en
# 1     False  1523145                ru
# 2     False    83533                en
# 3     False   980431                en
# 4     False  1470130                en
# ...     ...      ...               ...
# 1995  False    59440                en
# 1996  False   537996                en
# 1997  False      756                en
# 1998  False     9374                en
# 1999  False     1893                en
#
#                                  original_title  \
# ...

# %%
df_final2.columns
# Out:
# Index(['adult', 'id', 'original_language', 'original_title', 'overview',
#        'popularity', 'release_date', 'title', 'vote_average', 'genres',
#        'weighted_rating', 'genres_text', 'content', 'release_year'],
#       dtype='object')

# %%
# Drop the column Original title as it is not useful
df_final2 = df_final2.drop(columns = ["original_title"])
df_final2
# Out:
#       adult       id original_language  \
# 0     False  1226863                en
# 1     False  1523145                ru
# 2     False    83533                en
# 3     False   980431                en
# 4     False  1470130                en
# ...     ...      ...               ...
# 1995  False    59440                en
# 1996  False   537996                en
# 1997  False      756                en
# 1998  False     9374                en
# 1999  False     1893                en
#
#                                                overview  popularity  \
# 0     Having thwarted Bowser's previous plot to marr...    1.000000
# 1     High school student Polina is saved from bully...    0.521580
# 2     In the wake of the devastating war against the...    0.394803
# 3     Avatar Aang, the world's last Airbender, learn...    0.378295
# 4     Rebecca Owens, a recent mortuary science gradu...    0.314978
# ...                                                 ...         ...
# ...

# %%
# Data is cleaned so we can use it for the recommendation system. We will save it as a csv file and in a PostgreSQL database.

df_final2.to_csv("movies_information.csv", index=False)

# %%
# comand to save the dataframe in a PostgreSQL database:

# docker run --name postgres-db \
#-e POSTGRES_USER=admin \
#-e POSTGRES_PASSWORD=admin \
#-e POSTGRES_DB=movies_db \
#-p 5432:5432 \
#-d postgres

df_final2 = pd.read_csv("data\movies_information_with_embeddings_all.csv")

engine = create_engine("postgresql://admin:admin@localhost:5432/movies_db")

# %%
# Prove that all is working well
with engine.connect() as connection:
    result = connection.execute(text("SELECT 1"))
    print(result.fetchone())
# Out:
# (1,)

# %%
# Save the Dataframe in the PostgreSQL database
df_final2.to_sql("movies_information", engine, if_exists="replace", index=False)
# Out:
# 725

# %% [markdown]
# #### Make a query in my Postgres DB

# %%
# !pip install psycopg2-binary pandas
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 26.0.1 is available.
# You should consider upgrading via the 'C:\Users\34651\Desktop\python_projects\movie-recomendation-system\.venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import psycopg2

conn = psycopg2.connect(
    dbname="movies_db",
    user="admin",
    password="admin",
    host="localhost",
    port="5432"
)

conn.rollback()

cur = conn.cursor()

# %%
cur.execute("SELECT current_database();")
print(cur.fetchone())
# Out:
# ('movies_db',)

# %%
conn.rollback()

# Show the name of the columns
cur.execute("""
SELECT column_name
FROM information_schema.columns
WHERE table_name = 'movies';
""")

columnas = cur.fetchall()
for columna in columnas:
    print(columna[0])
# Out:
# vote_average
# popularity
# weighted_rating
# release_year
# embedding
# id
# adult
# overview
# title
# content
# original_language
# release_date
# genres

# %%
# %pip install tabulate
# Out:
# ...
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 26.0.1 is available.
# You should consider upgrading via the 'c:\Users\34651\Desktop\python_projects\movie-recomendation-system\.venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
from tabulate import tabulate

conn.rollback()

cur.execute("""
SELECT id, title, vote_average, release_year, genres, weighted_rating
FROM movies
WHERE title ILIKE '%La La Land%';
""")

resultados = cur.fetchall()

# Obtener nombres de columnas
nombres_columnas = [desc[0] for desc in cur.description]

# Mostrar como tabla
print(tabulate(resultados, headers=nombres_columnas, tablefmt="grid"))
# Out:
# +--------+------------+----------------+----------------+--------------------------------+-------------------+
# |     id | title      |   vote_average |   release_year | genres                         |   weighted_rating |
# +========+============+================+================+================================+===================+
# | 313369 | La La Land |       0.863169 |           2016 | ['Comedy', 'Drama', 'Romance'] |           0.79022 |
# +--------+------------+----------------+----------------+--------------------------------+-------------------+

# %%
from tabulate import tabulate

conn.rollback()

cur.execute("""
SELECT DISTINCT genres
FROM movies
WHERE 'Science Fiction' = ANY(genres);
""")

resultados = cur.fetchall()

# Obtener nombres de columnas
nombres_columnas = [desc[0] for desc in cur.description]

# Mostrar como tabla
print(tabulate(resultados, headers=nombres_columnas, tablefmt="grid"))
# Out:
# +----------------------------------------------------------------------------------------+
# | genres                                                                                 |
# +========================================================================================+
# | ['Animation', 'Family', 'Science Fiction']                                             |
# +----------------------------------------------------------------------------------------+
# | ['Family', 'Comedy', 'Animation', 'Science Fiction', 'Action']                         |
# +----------------------------------------------------------------------------------------+
# | ['Thriller', 'Mystery', 'Science Fiction']                                             |
# +----------------------------------------------------------------------------------------+
# | ['Comedy', 'Drama', 'Science Fiction']                                                 |
# ...

# %%
conn.rollback()

cur.execute("""
SELECT  DISTINCT EMBEDDING
FROM movies;
""")

rows = cur.fetchall()
rows
# Out:
# [('[-1.7922406,0.24212423,-3.6774147,-0.69136316,-0.0013265571,-0.20784636,-0.1422342,-0.2334718,-0.36156455,-0.37264508,-0.7357561,0.87604713,1.2656784,1.3152814,1.2663773,-0.7871379,0.5404731,-1.1287447,-0.48396343,0.48380512,-1.0360208,0.6095385,-0.5487653,-0.40788794,2.5966012,0.24136038,-0.107516386,-0.24628893,0.008065929,0.6267199,-0.16213007,-0.022115301,-0.4178202,0.41805053,-1.4301919,0.88745236,1.4057753,0.65780556,0.26687178,0.5102855,0.47600308,0.13521431,0.9038925,-0.47438043,0.72758967,-0.7272512,0.30154353,-0.53809845,0.8942334,-0.07145779,-0.2876353,0.032106347,0.37316236,-0.372358,0.83259964,0.087833315,0.100192696,0.3806218,-0.15189718,0.30590472,1.3983032,0.82809293,-0.44706118,0.9407892,0.5412123,-1.2962295,0.16505443,1.2558113,-0.09243817,-1.128858,0.77914464,-0.06520086,0.60237974,0.21295144,-0.5715501,0.107726224,0.1913834,0.4247726,-0.9153204,0.54051226,0.5729336,-0.8137811,1.2347639,-0.2795977,0.63508236,0.095781446,-0.9285483,0.25031725,-1.971188,1.224372,0
# ...

# %%
cur.execute("""
SELECT genres, pg_typeof(genres)
FROM movies
LIMIT 10;
""")

cur.fetchall()
# Out:
# [(['Family', 'Comedy', 'Adventure', 'Fantasy', 'Animation'], 'text[]'),
#  (['Romance', 'Drama'], 'text[]'),
#  (['Science Fiction', 'Adventure', 'Fantasy'], 'text[]'),
#  (['Animation', 'Action', 'Adventure', 'Fantasy'], 'text[]'),
#  (['Horror', 'Mystery'], 'text[]'),
#  (['Science Fiction', 'Adventure'], 'text[]'),
#  (['Animation', 'Family', 'Science Fiction', 'Comedy', 'Adventure'], 'text[]'),
#  (['Horror', 'Thriller'], 'text[]'),
#  (['Comedy', 'Romance'], 'text[]'),
#  (['Comedy', 'Action', 'Adventure'], 'text[]')]

# %%
conn.rollback()
cur.execute("""
SELECT id, title, genres
FROM movies
WHERE genres && ARRAY['Comedy']::text[]
LIMIT 10;
""")

cur.fetchall()
# Out:
# [(1226863,
#   'The Super Mario Galaxy Movie',
#   ['Family', 'Comedy', 'Adventure', 'Fantasy', 'Animation']),
#  (1327819,
#   'Hoppers',
#   ['Animation', 'Family', 'Science Fiction', 'Comedy', 'Adventure']),
#  (20222, 'Sex with Love', ['Comedy', 'Romance']),
#  (1084577, 'Balls Up', ['Comedy', 'Action', 'Adventure']),
#  (1198994, 'Send Help', ['Horror', 'Thriller', 'Comedy']),
#  (502356,
#   'The Super Mario Bros. Movie',
#   ['Family', 'Comedy', 'Adventure', 'Fantasy', 'Animation']),
#  (1297842, 'GOAT', ['Animation', 'Comedy', 'Family']),
#  (1084242,
#   'Zootopia 2',
#   ['Animation', 'Family', 'Mystery', 'Adventure', 'Comedy']),
#  (1049471, 'Outcome', ['Comedy', 'Drama']),
#  (1234731, 'Anaconda', ['Adventure', 'Comedy', 'Horror'])]
